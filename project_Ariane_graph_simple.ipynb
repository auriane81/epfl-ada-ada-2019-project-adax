# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import gzip
import copy
import pickle as pk
import heapq as hp

import networkx as nx
from networkx.algorithms import bipartite, components, shortest_paths

# %% [markdown]
# # Importing the datasets, cleaning, transforming

# %%
products_litteral = pd.read_pickle('products_litteral.pk')

# %% [markdown]
# # Making graphs

# %%
with open('food_aisles.pk', 'rb') as file:
    food_aisles = pk.load(file)

# %%
by_aisle = {}
for aisle in food_aisles:
    by_aisle[aisle] = pd.read_pickle('by_aisle_'+aisle+'.pk')

# %%
def find_recommendation_path(source_id, G=None, aisle=None, health_thresh=2, product_scores=None, hscores=None, fscores=None, alpha=.3, beta=.2):
    if G is None:
        G = nx.read_gpickle('thresholded_inv_'+aisle+'.gpk')
    if product_scores is None:
        product_scores = pd.read_pickle('product_scores')
        
    targets = set()
    for x in G.nodes:
        if x in product_scores.index and product_scores.at[x, "healthiness"] >= health_thresh:
            targets.add(x)
            
    # do not allow paths through even less healthy products:
    G_ok = G.subgraph({x for x in G.nodes if x in product_scores.index and product_scores.at[x, "healthiness"] >= product_scores.at[source_id, "healthiness"]})
    pred, lengths = nx.dijkstra_predecessor_and_distance(G_ok, source_id, weight='weight')
    candidates = [(-np.inf, None)]
    sep = []
    for candidate in targets:
        if candidate not in lengths:
            sep.append(candidate)
        if candidate in lengths and - lengths[candidate] > candidates[0][0]:   # ie candidate is closer than all current candidates
            if len(candidates) >= 10:
                hp.heappop(candidates)
            hp.heappush(candidates, (- lengths[candidate], candidate))
    #if fscores is None:
    #    fscores = pd.read_pickle('fidelity_scores.pk')
    if len(sep) == len(targets):
        print("not connected to a healthy product")
        return
    rec = (0, None)
    fids = []
    dists = []
    healths = []
    if candidates == [(-np.inf, None)]:
        print('No path to healthy products')
        return
    for (mdist, candidate) in candidates:
        if mdist == -np.inf:
            continue
        fids.append(product_scores.at[candidate, 'fidelity'])
        dists.append(- mdist)
        healths.append(product_scores.at[candidate, 'healthiness'])
    max_fid = max(fids)
    min_fid = min(fids)
    max_dist = max(dists)
    min_dist = min(dists)
    max_health = max(healths)
    min_health = min(healths)
    for (mdist, candidate) in candidates:
        if mdist == -np.inf:
            continue
        fid = ((product_scores.at[candidate, 'fidelity'] - min_fid) / (max_fid - min_fid)) if max_fid != min_fid else 0
        dist = ((max_dist + mdist) / (max_dist - min_dist)) if max_dist != min_dist else 0
        health = ((product_scores.at[candidate, "healthiness"] - min_health) / (max_health - min_health)) if max_health != min_health else 0
        score = (1+health)**alpha * (1+fid)**beta * (1+dist)**(1-alpha-beta)
        if score > rec[0]:
            rec = (score, candidate)
    orig = rec[1]
    path = [orig]
    while orig != source_id:
        orig = pred[orig][0]
        path.append(orig)
    return path


# Prints some good and bad examples of predictions

good_product_ids = [8923,16419,4313,12218,516]
bad_product_ids = [28199,6184, 14809]

print("Good recommendation examples : ")
for p in good_product_ids :
    target = find_recommendation_path(row.product_id, aisle=prod_lit.at[row.product_id, 'aisle'], product_scores=product_scores)[0]
    s = prod_lit.at[p, 'product_name']+' should be replaced by '+ prod_lit.at[target, 'product_name']+ ' (healthiness gain = '+str (round(product_scores.at[target, 'healthiness']-product_scores.at[p, 'healthiness'],2))+")"
    print(s)
    
print("\nBad or strange recommendation examples : ")
for p in bad_product_ids :
    target = find_recommendation_path(row.product_id, aisle=prod_lit.at[row.product_id, 'aisle'], product_scores=product_scores)[0]
    s = prod_lit.at[p, 'product_name']+' should be replaced by '+ prod_lit.at[target, 'product_name']+ ' (healthiness gain = '+str (round(product_scores.at[target, 'healthiness']-product_scores.at[p, 'healthiness'],2))+")"
    print(s)

# %%
product_scores = pd.read_pickle('GOOD_product_scores.pk')

# %%
product_scores.head()
# Out:
#             healthiness  count  fidelity
# product_id
# 1             -0.090730    507  0.679629
# 2              2.476190     21  0.093217
# 3              1.306452     62  1.630632
# 4             -0.166667     90  0.975122
# 5              3.250000      4  1.829932

# %%
# Find real recommendations
with open('THE_GOOD_users_cluster.pk', 'rb') as f:
    users_cluster = pk.load(f)

# %%
prod_lit = products_litteral.set_index('product_id')
prod_lit.head()
# Out:
#                                               product_name          aisle  \
# product_id
# 1                               Chocolate Sandwich Cookies  cookies cakes
# 78                       Nutter Butter Cookie Bites Go-Pak  cookies cakes
# 102                                  Danish Butter Cookies  cookies cakes
# 172         Gluten Free All Natural Chocolate Chip Cookies  cookies cakes
# 285                           Mini Nilla Wafers Munch Pack  cookies cakes
#
#            department
# product_id
# 1              snacks
# 78             snacks
# 102            snacks
# 172            snacks
# 285            snacks

# %%
unhealthy_food_orders = pd.read_pickle('unhealthy_food_orders.pk')

# %%
unhealthy_food_orders.head()
# Out:
#      user_id  product_id
# 150        4        1200
# 151        4       17769
# 152        4       43704
# 153        4       37646
# 154        4       11865

# %%
some_unhealthy_orders = unhealthy_food_orders.sample(100)

# %%
some_unhealthy_orders.head()
# Out:
#           user_id  product_id
# 14177866   204571       12761
# 8808          154       48395
# 6961760     99996       16891
# 13144050   189571       40396
# 9491310    136847       42701

# %%
for _, row in some_unhealthy_orders.iterrows():
    try:
        print('For product_id= ', row.product_id)
        print('Path from', prod_lit.at[row.product_id, 'product_name'], 'with healthiness', product_scores.at[row.product_id, 'healthiness'])
        path = find_recommendation_path(row.product_id, aisle=prod_lit.at[row.product_id, 'aisle'], product_scores=product_scores)
        target = path[0]
        print('To', prod_lit.at[target, 'product_name'], 'with healthiness', product_scores.at[target, 'healthiness'])
        print()
    except:
        print('============================= Echec: For user ', row.user_id)
        print('Path from', prod_lit.at[row.product_id, 'product_name'], 'with healthiness', product_scores.at[row.product_id, 'healthiness'])
        print()
# Out:
# For product_id=  46735
# Path from Cherry Caffeine Free Unsweetened Soft Drink Mix with healthiness 1.4
# Nb of targets: 42
# To Pink Lemonade Unsweetened Soft Drink Mix with healthiness 3.0
#
# For product_id=  8736
# Path from Synergy Organic & Raw Cosmic Cranberry with healthiness 1.880787037037037
# Nb of targets: 254
# To Organic Raw Kombucha Gingerade with healthiness 2.34447523380672
#
# For product_id=  21938
# Path from Green Bell Pepper with healthiness 3.494960073308025
# Nb of targets: 519
# To Organic Garlic with healthiness 3.51486216932082
#
# For product_id=  34222
# Path from Squeeze Grape Jelly with healthiness 0.5653846153846154
# Nb of targets: 250
# To Organic Creamy Peanut Butter with healthiness 2.4247073072264835
#
# For product_id=  28199
# Path from Clementines, Bag with healthiness 1.7839971295299606
# Nb of targets: 326
# To Organic Baby Spinach with healthiness 2.8187180907607314
#
# For product_id=  36929
# Path from Milk, Vitamin D with healthiness 2.4545454545454546
# Nb of targets: 96
# To Organic Whole Grassmilk Milk with healthiness 2.744376757263355
#
# For product_id=  8923
# Path from Chocolate Milk Cartons 2% Reduced Fat with healthiness 0.33035714285714285
# Nb of targets: 96
# To Organic Whole Milk with healthiness 2.557040672479507
#
# For product_id=  32019
# Path from Chicken Carbonara with healthiness -0.11258278145695365
# Nb of targets: 49
# To Organic Brown Rice with healthiness 2.5913242009132422
#
# For product_id=  11365
# Path from Leaf Spinach with healthiness 1.4995857497928748
# Nb of targets: 4
# To Butter Lettuce with healthiness 2.1941747572815533
#
# For product_id=  6184
# Path from Clementines with healthiness 0.7624347826086957
# Nb of targets: 4
# To Butter Lettuce with healthiness 2.1941747572815533
#
# For product_id=  39877
# Path from Organic Granny Smith Apple with healthiness 2.5854737618286836
# Nb of targets: 230
# To Limes with healthiness 2.9324543141337034
#
# For product_id=  16419
# Path from Sweet Sliced Bread with healthiness 0.6463157894736842
# Nb of targets: 292
# To Ezekiel 4:9 Bread Organic Sprouted Whole Grain with healthiness 2.7213442688537706
#
# For product_id=  16219
# Path from Fine Granulated Sugar with healthiness 1.5
# Nb of targets: 341
# To Organic Unbleached All-Purpose Flour with healthiness 2.8996948893974066
#
# For product_id=  21553
# Path from Lowfat 2% Milkfat Cottage Cheese with healthiness 1.4008264462809918
# Nb of targets: 76
# To Organic Sour Cream with healthiness 2.948473282442748
#
# For product_id=  43713
# Path from Organic Creamy Peanut Butter with healthiness 2.4247073072264835
# Nb of targets: 250
# To Peanut Butter Creamy With Salt with healthiness 2.687048360200111
#
# For product_id=  37895
# Path from Shredded Steak Taquitos with healthiness 0.3287671232876712
# Nb of targets: 84
# To Organic Seasoned Yukon Select Potatoes Hashed Browns with healthiness 2.618570474281897
#
# For product_id=  46145
# Path from Whole Berry Cranberry Sauce with healthiness 1.1956521739130435
# Nb of targets: 60
# To Organic AppleApple with healthiness 2.2185655923740355
#
# For product_id=  43831
# Path from Extra Dry Champagne with healthiness 0.0425531914893617
# Nb of targets: 16
# To Brut Premier with healthiness 4.0
#
# For product_id=  42447
# Path from 100% Juice with healthiness 0.46130952380952384
# Nb of targets: 270
# To Natural Premium Coconut Water with healthiness 2.385560215698023
#
# For product_id=  14809
# Path from Organic Earl Grey Black Tea Bags 15 Count with healthiness 1.6440677966101696
# Nb of targets: 323
# To Breakfast Americana with healthiness 2.1776315789473686
#
# For product_id=  24852
# Path from Banana with healthiness 2.162924039755747
# Nb of targets: 230
# To Organic Avocado with healthiness 2.676720345399112
#
# For product_id=  4313
# Path from Star Wars Italian Sweet Creme Creamer with healthiness 0.6918604651162791
# Nb of targets: 35
# To Organic Heavy Whipping Cream with healthiness 2.9727683122178536
#
# For product_id=  44887
# Path from Balsamic Imported Vinegar with healthiness 2.08
# Nb of targets: 234
# To Balsamic Imported Vinegar with healthiness 2.08
#
# For product_id=  10132
# Path from Organic American Cheese Singles with healthiness 2.202858277094085
# Nb of targets: 384
# To Organic American Cheese Singles with healthiness 2.202858277094085
#
# For product_id=  29239
# Path from Ultra Thin Crust Sausage & Uncured Pepperoni Pizza with healthiness 0.4864864864864865
# Nb of targets: 48
# To Mediterranean Thin Crust Pizza with healthiness 2.2205638474295193
#
# For product_id=  12218
# Path from Classic Wheat Bread with healthiness 0.8846611177170036
# Nb of targets: 292
# To Ezekiel 4:9 Bread Organic Sprouted Whole Grain with healthiness 2.7213442688537706
#
# For product_id=  47006
# Path from Steak Sauce with healthiness 0.8779342723004695
# Nb of targets: 165
# To Panko Bread Crumbs with healthiness 3.0233224222585924
#
# For product_id=  37722
# Path from Gluten Freen Original Rice Pudding with healthiness 0.7574750830564784
# Nb of targets: 15
# To Natural Black Cherry Gels Gelatin Free Snacks with healthiness 2.463743676222597
#
# For product_id=  1695
# Path from Major Dickason's Blend Ground Coffee Dark Roast with healthiness 1.7589616810877626
# Nb of targets: 158
# To Compostable Coffee Filters with healthiness 2.4671280276816607
#
# For product_id=  516
# Path from American Cheese Slices with healthiness 0.9586776859504132
# Nb of targets: 384
# To Sharp Cheddar Cheese with healthiness 2.6874849578820696
#
# For product_id=  10731
# Path from Greek 100 Yogurt Banana Caramel with healthiness -0.25
# Nb of targets: 449
# To Total Greek Strained Yogurt with healthiness 2.6606493331537115
#
# For product_id=  12081
# Path from Soft Rye Loaf Bread with healthiness 0.022222222222222223
# Nb of targets: 292
# To Ezekiel 4:9 Bread Organic Sprouted Whole Grain with healthiness 2.7213442688537706
#
# For product_id=  41434
# Path from Vanilla Ice Cream Sandwiches with healthiness 0.43103448275862066
# Nb of targets: 350
# To Ice Cream Chocolate Mocha Chip with healthiness 2.3899676375404533
#
# For product_id=  33756
# Path from Crispy Chicken Strips 100% All Natural Fully Cooked with healthiness 0.023076923076923078
# Nb of targets: 84
# To Organic Seasoned Yukon Select Potatoes Hashed Browns with healthiness 2.618570474281897
#
# For product_id=  14705
# Path from Pie Crusts with healthiness 1.614814814814815
# Nb of targets: 149
# To Ready-to-Bake 9 Inch Pie Crusts with healthiness 2.9522144522144522
#
# For product_id=  24489
# Path from Organic Whole Strawberries with healthiness 2.7243986254295534
# Nb of targets: 169
# To Organic Dark Sweet Cherries with healthiness 2.8927845528455283
#
# For product_id=  45615
# Path from Organic Apple Sauce with healthiness 2.4948979591836733
# Nb of targets: 60
# To Organic Applesauce Unsweetened with healthiness 3.1481481481481484
#
# For product_id=  39685
# Path from Frontier Straight 95% Rye Mash Whiskey with healthiness 1.7333333333333334
# Nb of targets: 27
# To Extra Dry Vermouth with healthiness 3.142857142857143
#
# For product_id=  21903
# Path from Organic Baby Spinach with healthiness 2.8187180907607314
# Nb of targets: 326
# To Organic Baby Arugula with healthiness 2.9609010618239555
#
# For product_id=  40571
# Path from Total 2% Greek Strained Yogurt with Cherry 5.3 oz with healthiness 1.807125307125307
# Nb of targets: 449
# To Total Greek Strained Yogurt with healthiness 2.6606493331537115
#
# For product_id=  46906
# Path from Grape White/Green Seedless with healthiness 2.3687022197660497
# Nb of targets: 230
# To Organic Hass Avocado with healthiness 2.670946515943985
#
# For product_id=  27511
# Path from Milk, Organic, Fat Free with healthiness 2.010652463382157
# Nb of targets: 96
# To Milk, Organic, Fat Free with healthiness 2.010652463382157
#
# For product_id=  4920
# Path from Seedless Red Grapes with healthiness 2.160955796569157
# Nb of targets: 326
# To Organic Baby Spinach with healthiness 2.8187180907607314
#
# For product_id=  38228
# Path from Monster Trail Mix with healthiness -0.24890829694323144
# Nb of targets: 12
# To Raw Snack, TigerNut, Original with healthiness 2.72
#
# For product_id=  13807
# Path from Light and Lean Macaroni and Cheese with healthiness 1.3962765957446808
# Nb of targets: 49
# To Organic Brown Rice with healthiness 2.5913242009132422
#
# For product_id=  45005
# Path from Sourdough Deli Bread with healthiness 1.34472049689441
# Nb of targets: 292
# To Ezekiel 4:9 Bread Organic Sprouted Whole Grain with healthiness 2.7213442688537706
#
# For product_id=  24838
# Path from Unsweetened Almondmilk with healthiness 2.4074262461851474
# Nb of targets: 175
# To Organic Coconut Milk with healthiness 3.3096594673380153
#
# For product_id=  10799
# Path from Sweet Honey Mustard with healthiness 2.4583333333333335
# Nb of targets: 238
# To Sweet Honey Mustard with healthiness 2.4583333333333335
#
# For product_id=  23029
# Path from Organic Uncured Sliced Black Forest Ham with healthiness 2.589631480324797
# Nb of targets: 119
# To Rosemary Ham with healthiness 2.8194444444444446
#
# For product_id=  22866
# Path from Sharp Cheddar Cheese Shredded with healthiness 2.050301810865191
# Nb of targets: 384
# To Sharp Cheddar Cheese Shredded with healthiness 2.050301810865191
#
# For product_id=  29145
# Path from Green Tea Blueberry Pomegranate with healthiness 1.5781990521327014
# Nb of targets: 323
# To Organic Unsweetened Lemon Iced Green Tea with healthiness 2.169811320754717
#
# For product_id=  12341
# Path from Hass Avocados with healthiness 1.9221343591935598
# Nb of targets: 4
# To Butter Lettuce with healthiness 2.1941747572815533
#
# For product_id=  4232
# Path from Ambrosia, Medium Roast with healthiness 1.9681159420289855
# Nb of targets: 158
# To Jacob's Wonderbar Dark Roast with healthiness 2.187258687258687
#
# For product_id=  12384
# Path from Organic Lactose Free 1% Lowfat Milk with healthiness 2.4063386944181646
# Nb of targets: 175
# To Organic Lactose Free 1% Lowfat Milk with healthiness 2.4063386944181646
#
# For product_id=  44422
# Path from Organic Old Fashioned Rolled Oats with healthiness 2.800900900900901
# Nb of targets: 142
# To Gluten Free Quick Cooking Oats with healthiness 2.8597972972972974
#
# For product_id=  43565
# Path from Lean Ground Turky with healthiness 1.9638752052545156
# Nb of targets: 46
# To Boneless Skinless Chicken Breasts with healthiness 3.0361839715178376
#
# For product_id=  13176
# Path from Bag of Organic Bananas with healthiness 2.283886715040079
# Nb of targets: 230
# To Organic Hass Avocado with healthiness 2.670946515943985
#
# For product_id=  24561
# Path from Organic Cheese Frozen Pizza with healthiness 2.056219791401679
# Nb of targets: 48
# To Margherita With Cherry Tomatoes Pizza with healthiness 2.2325581395348837
#
# For product_id=  41400
# Path from Crunchy Oats 'n Honey Granola Bars with healthiness 0.04943273905996758
# Nb of targets: 257
# To Peanut Butter Chocolate Chip Fruit & Nut Food Bar with healthiness 2.061951219512195
#
# For product_id=  8375
# Path from Ice Sugar Free Peppermint Gum with healthiness 0.4722222222222222
# Nb of targets: 14
# To Peppermint Mint Roll with healthiness 3.1666666666666665
#
# For product_id=  23909
# Path from 2% Reduced Fat Milk with healthiness 1.0432296210138605
# Nb of targets: 96
# To Organic Whole Milk with healthiness 2.557040672479507
#
# For product_id=  26348
# Path from Mixed Fruit Fruit Snacks with healthiness -0.03384947785379906
# Nb of targets: 101
# To Apple Cinnamon GoGo Squeez with healthiness 2.2198757763975157
#
# For product_id=  15248
# Path from India Pale Ale Racer 5 with healthiness 0.0
# Nb of targets: 44
# To Session IPA with healthiness 3.0
#
# For product_id=  31334
# Path from Chocolate Almond & Sea Salt with Chia Granola Bars with healthiness 0.9920948616600791
# Nb of targets: 257
# To Peanut Butter Chocolate Chip Fruit & Nut Food Bar with healthiness 2.061951219512195
#
# For product_id=  3023
# Path from Club & Cheddar Sandwich Crackers with healthiness 0.023952095808383235
# Nb of targets: 272
# To 6 OZ LA PANZANELLA CROSTINI ORIGINAL CRACKERS with healthiness 2.28561736770692
#
# For product_id=  7751
# Path from Tomato Ketchup with healthiness 1.6824228700820831
# Nb of targets: 238
# To Organic Mayonnaise with healthiness 2.7967611336032387
#
# For product_id=  20883
# Path from Carving Board Slow Cooked Ham with healthiness 1.2040816326530612
# Nb of targets: 119
# To Organic Roasted Turkey Breast with healthiness 2.3684143385635923
#
# For product_id=  13885
# Path from Caramel Cookie Crunch Gelato with healthiness 1.9708416169648775
# Nb of targets: 350
# To Talenti Double Dark Chocolate Gelato with healthiness 2.2792494481236205
#
# For product_id=  6448
# Path from Smartfood White Cheddar Cheese Popcorn with healthiness 0.45980707395498394
# Nb of targets: 56
# To Baked Aged White Cheddar Rice and Corn Puffs with healthiness 2.2952204911539478
#
# For product_id=  41774
# Path from XX Espresso Iced Coffee With Almond Milk with healthiness 1.6390625
# Nb of targets: 158
# To Coffee Cold Brew Fs W Mcts with healthiness 2.4237288135593222
#
# For product_id=  26795
# Path from Snack Mix Original Recipe with healthiness -0.10204081632653061
# Nb of targets: 318
# To Sea Salt Pita Chips with healthiness 2.2629550321199146
#
# For product_id=  21573
# Path from Roasted Pine Nut Hummus with healthiness 0.9425396825396826
# Nb of targets: 160
# To Original Hummus with healthiness 2.5414513023208674
#
# For product_id=  28156
# Path from Total 0% Nonfat Plain Greek Yogurt with healthiness 2.5724530168150346
# Nb of targets: 449
# To Whole Milk Plain Yogurt with healthiness 3.0072202166064983
#
# For product_id=  810
# Path from Organic Honey Mustard with healthiness 2.5353982300884956
# Nb of targets: 238
# To Organic Tahini with healthiness 3.2708578143360754
#
# For product_id=  4957
# Path from Total 2% Lowfat Greek Strained Yogurt With Blueberry with healthiness 1.8431338335369045
# Nb of targets: 449
# To Total Greek Strained Yogurt with healthiness 2.6606493331537115
#
# For product_id=  10145
# Path from Simple Favorites Chicken Enchilada Suiza with healthiness -0.17135549872122763
# Nb of targets: 49
# To Organic Brown Rice with healthiness 2.5913242009132422
#
# For product_id=  26201
# Path from Chicken Taquitos with healthiness 1.9222614840989398
# Nb of targets: 84
# To Chicken Breast Tenders Breaded with healthiness 2.439323467230444
#
# For product_id=  17191
# Path from Tangerine with healthiness 1.5341296928327646
# Nb of targets: 52
# To Superior Tonic Water with healthiness 2.8194444444444446
#
# For product_id=  25435
# Path from Original Lemonade with healthiness 1.9197994987468672
# Nb of targets: 80
# To Italian Sparkling Mineral Water with healthiness 2.645234133586879
#
# For product_id=  37317
# Path from Wonderful 100% Pomegranate Juice with healthiness 1.8186695278969958
# Nb of targets: 254
# To 100% Raw Coconut Water with healthiness 2.296306926903942
#
# For product_id=  23540
# Path from Orange with healthiness 0.7707865168539326
# Nb of targets: 22
# To Organic Blood Orange Energy Drink with healthiness 2.4029850746268657
#
# For product_id=  22656
# Path from Tomato Condensed Soup with healthiness 0.765
# Nb of targets: 236
# To Beef Broth with healthiness 2.0344827586206895
#
# For product_id=  24852
# Path from Banana with healthiness 2.162924039755747
# Nb of targets: 230
# To Organic Avocado with healthiness 2.676720345399112
#
# For product_id=  22069
# Path from Sea Salt Caramel Frozen Greek Yogurt Bars with healthiness 1.565110565110565
# Nb of targets: 350
# To Mediterranean Mint Gelato with healthiness 2.0985221674876846
#
# For product_id=  37646
# Path from Organic Gala Apples with healthiness 2.3945537960633416
# Nb of targets: 230
# To Organic Hass Avocado with healthiness 2.670946515943985
#
# For product_id=  34531
# Path from Veranda Blend Blonde Ground Coffee with healthiness 0.5251396648044693
# Nb of targets: 158
# To Compostable Coffee Filters with healthiness 2.4671280276816607
#
# For product_id=  44107
# Path from Uncrustables Reduced Sugar, Peanut Butter & Strawberry Spread Sandwich on Whole Wheat Bread with healthiness -0.6140350877192983
# Nb of targets: 49
# To Organic Brown Rice with healthiness 2.5913242009132422
#
# For product_id=  45432
# Path from Brewmaster's Seasonal Sampler with healthiness 0.03535353535353535
# Nb of targets: 44
# To Session IPA with healthiness 3.0
#
# For product_id=  27360
# Path from Boneless Skinless Chicken Breast Fillets with healthiness 1.1651835372636263
# Nb of targets: 46
# To Boneless Skinless Chicken Breasts with healthiness 3.0361839715178376
#
# For product_id=  8571
# Path from Baby Cucumbers with healthiness 1.2344139650872819
# Nb of targets: 4
# To Butter Lettuce with healthiness 2.1941747572815533
#
# For product_id=  41963
# Path from Organic Kale Berry Smoothie Kickstart with healthiness 2.1414141414141414
# Nb of targets: 169
# To Organic Mango Peach Carrot Kickstart Smoothie with healthiness 2.4835164835164836
#
# For product_id=  26317
# Path from Organic Lemonade with healthiness 1.8420408163265307
# Nb of targets: 270
# To Organic Orange Juice with healthiness 2.5098892405063293
#
# For product_id=  42828
# Path from Whipped Cream Cheese with healthiness 2.396595943110282
# Nb of targets: 76
# To Organic Sour Cream with healthiness 2.948473282442748
#
# For product_id=  42460
# Path from Plain Mini Bagels with healthiness 1.1531291611185086
# Nb of targets: 65
# To Plain Bagelettes with healthiness 2.4855072463768115
#
# For product_id=  955
# Path from Cheddar Chex Mix with healthiness -0.0625
# Nb of targets: 12
# To Raw Snack, TigerNut, Original with healthiness 2.72
#
# For product_id=  8501
# Path from Breakfast Blend Medium Keurig Brewed K-Cups Ground Coffee with healthiness 0.8177842565597667
# Nb of targets: 158
# To Newman's Special Decaf Extra Bold Medium Roast K-Cup Packs with healthiness 2.0
#
# For product_id=  18465
# Path from Organic Grade A Free Range Large Brown Eggs with healthiness 2.6685082872928176
# Nb of targets: 74
# To Large Alfresco Eggs with healthiness 2.8811431623931623
#
# For product_id=  32691
# Path from Vanilla Ice Cream with healthiness 1.835562310030395
# Nb of targets: 350
# To Ice Cream Chocolate Mocha Chip with healthiness 2.3899676375404533
#
# For product_id=  25146
# Path from Original Orange Juice with healthiness 1.6700911590218492
# Nb of targets: 254
# To 100% Raw Coconut Water with healthiness 2.296306926903942
#
# For product_id=  2054
# Path from Belgium Beer with healthiness 0.6
# Nb of targets: 44
# To 1500 Pale Ale with healthiness 3.2222222222222223

# %%
# Prints some good and bad examples of predictions

good_product_ids = [8923,16419,4313,12218,516]
bad_product_ids = [28199,6184, 14809]

print("Good recommendation examples : ")
for p in good_product_ids :
    target = find_recommendation_path(row.product_id, aisle=prod_lit.at[row.product_id, 'aisle'], product_scores=product_scores)[0]
    s = prod_lit.at[p, 'product_name']+' should be replaced by '+ prod_lit.at[target, 'product_name']+ ' (healthiness gain = '+str (round(product_scores.at[target, 'healthiness']-product_scores.at[p, 'healthiness'],2))+")"
    print(s)
    
print("\nBad or strange recommendation examples : ")
for p in bad_product_ids :
    target = find_recommendation_path(row.product_id, aisle=prod_lit.at[row.product_id, 'aisle'], product_scores=product_scores)[0]
    s = prod_lit.at[p, 'product_name']+' should be replaced by '+ prod_lit.at[target, 'product_name']+ ' (healthiness gain = '+str (round(product_scores.at[target, 'healthiness']-product_scores.at[p, 'healthiness'],2))+")"
    print(s)
# Out:
# Good recommendation examples :
# Nb of targets: 44
# Chocolate Milk Cartons 2% Reduced Fat should be replaced by 1500 Pale Ale (healthiness gain = 2.89)
# Nb of targets: 44
# Sweet Sliced Bread should be replaced by 1500 Pale Ale (healthiness gain = 2.58)
# Nb of targets: 44
# Star Wars Italian Sweet Creme Creamer should be replaced by 1500 Pale Ale (healthiness gain = 2.53)
# Nb of targets: 44
# Classic Wheat Bread should be replaced by 1500 Pale Ale (healthiness gain = 2.34)
# Nb of targets: 44
# American Cheese Slices should be replaced by 1500 Pale Ale (healthiness gain = 2.26)
#
# Bad or strange recommendation examples :
# Nb of targets: 44
# Clementines, Bag should be replaced by 1500 Pale Ale (healthiness gain = 1.44)
# Nb of targets: 44
# Clementines should be replaced by 1500 Pale Ale (healthiness gain = 2.46)
# Nb of targets: 44
# Organic Earl Grey Black Tea Bags 15 Count should be replaced by 1500 Pale Ale (healthiness gain = 1.58)

# %% [raw]
# For user  307
# Path from Organic Coconut Water with healthiness 0.3990885416666667
# Nb of targets: 80
# To Italian Sparkling Mineral Water with healthiness 2.645234133586879
# For user  16433
# Path from Broccoli Bunch with healthiness 2.078125
# Nb of targets: 519
# To Broccoli Bunch with healthiness 2.078125
# For user  14179
# Path from Water Mineral with healthiness -0.011093502377179081
# Nb of targets: 80
# To Italian Sparkling Mineral Water with healthiness 2.645234133586879
# For user  202355
# Path from Simply 100 Crunch Blueberry Cookie Crumble Non-Fat Greek Yogurt with healthiness 0.30303030303030304
# Nb of targets: 449
# To Organic Plain Whole Milk Yogurt with healthiness 2.7170563230605738
#
# For user  307
# Path from Organic Coconut Water with healthiness 0.3990885416666667
# Nb of targets: 80
# To Italian Sparkling Mineral Water with healthiness 2.645234133586879
# For user  16433
# Path from Broccoli Bunch with healthiness 2.078125
# Nb of targets: 519
# To Broccoli Bunch with healthiness 2.078125
# For user  14179
# Path from Water Mineral with healthiness -0.011093502377179081
# Nb of targets: 80
# To Italian Sparkling Mineral Water with healthiness 2.645234133586879
# For user  202355
# Path from Simply 100 Crunch Blueberry Cookie Crumble Non-Fat Greek Yogurt with healthiness 0.30303030303030304
# Nb of targets: 449
# To Organic Plain Whole Milk Yogurt with healthiness 2.7170563230605738
# For user  64793
# Path from Super B-Complex Key B Vitamins + Vitamin C Dietary Supplement Tablets with healthiness -0.6
# Echec: For user  64793
# Path from Super B-Complex Key B Vitamins + Vitamin C Dietary Supplement Tablets with healthiness -0.6
# For user  197225
# Path from Dairy Free Unsweetened Coconut Milk with healthiness 2.631650750341064
# Nb of targets: 175
# To Organic Coconut Milk with healthiness 3.3096594673380153
# For user  94446
# Path from Vanilla Almond Pecan Oatmeal Bowl with healthiness 1.0727272727272728
# Nb of targets: 142
# To Apple Cinnamon Pecan Oatmeal Cup with healthiness 2.3859649122807016
# For user  59931
# Path from Coconut Kale & Cacao Organic Superfoods Bar with healthiness 2.4545454545454546
# Nb of targets: 257
# To Superfood Cranberry, Almond & Lucuma Seedbar with healthiness 3.0
# For user  151541
# Path from Natural Premium Coconut Water with healthiness 2.385560215698023
# Nb of targets: 270
# To Organic Orange Juice with healthiness 2.5098892405063293
# For user  157312
# Path from Fresh Spinach with healthiness 2.1587301587301586
# Nb of targets: 326
# To Fresh Spinach with healthiness 2.1587301587301586
# For user  100948
# Path from Hass Avocado with healthiness 2.766289825282631
# Nb of targets: 519
# To Hass Avocado with healthiness 2.766289825282631
# For user  89598
# Path from Select Natural Applewood Smoked Turkey Breast with healthiness 1.0
# Nb of targets: 119
# To Organic Roasted Turkey Breast with healthiness 2.3684143385635923
# For user  157844
# Path from Penne Pasta with healthiness 1.5420780441937
# Nb of targets: 318
# To Rigatoni Pasta with healthiness 2.3333333333333335
# For user  184617
# Path from Shoestring Fries with healthiness 2.693464052287582
# Nb of targets: 84
# To Mini Vegetable Spring Rolls with healthiness 3.085714285714286
# For user  32635
# Path from Garlic Salt with healthiness 1.7508532423208192
# Nb of targets: 529
# To Oregano with healthiness 3.287958115183246
# For user  8090
# Path from Premium Chunk Light in Vegetable Oil Tuna with healthiness 1.9428571428571428
# Nb of targets: 124
# To Tonno, Tuna Solid White in Olive Oil with healthiness 2.9444444444444446
# For user  93512
# Path from Bacon & Bleu Chopped Salad Kit with healthiness 0.9534883720930233
# Nb of targets: 326
# To Baby Spinach with healthiness 2.705372616984402
# For user  93392
# Path from Unrefined Virgin Coconut Oil with healthiness 2.933384972889233
# Nb of targets: 234
# To Toasted Sesame Seed Oil with healthiness 3.356803044719315
# For user  198446
# Path from Cara Cara Oranges, Bag with healthiness 2.608695652173913
# Nb of targets: 230
# To Cara Cara Oranges, Bag with healthiness 2.608695652173913
# For user  188523
# Path from Original Whipped Topping with healthiness 0.9015625
# Nb of targets: 16
# To Pastry Kitchens Classic Puff Pastry with healthiness 3.2208835341365463

# %%
# mean healthiness per aisle
healthiness_per_aisle = {}
for aisle in food_aisles:
    healthiness_per_aisle[aisle] = pd.merge(by_aisle[aisle], product_scores, left_on='product_id', right_on='product_id')

# %%
for aisle in food_aisles:
    print(aisle, healthiness_per_aisle[aisle].mean()['healthiness'])
    print("====================")
# Out:
# butter 1.683022965208091
# ====================
# energy sports drinks 0.5959973106994256
# ====================
# soy lactosefree 2.049678544066623
# ====================
# ice cream ice 1.372019258082887
# ====================
# breakfast bakery 1.3105598454455978
# ====================
# coffee 1.23477358262605
# ====================
# marinades meat preparation 1.8484857537876438
# ====================
# kosher foods 2.2725794806356587
# ====================
# beers coolers 0.7434820461027672
# ====================
# canned meat seafood 1.8672391934007981
# ====================
# tortillas flat bread 2.0540074158785098
# ====================
# frozen meals 0.26754207134166325
# ====================
# cookies cakes 0.7943586097177386
# ====================
# chips pretzels 1.326160376033867
# ====================
# packaged vegetables fruits 1.8773111512029206
# ====================
# popcorn jerky 0.9440996708025281
# ====================
# fresh vegetables 3.175854541779337
# ====================
# candy chocolate 0.7567353956430564
# ====================
# salad dressing toppings 1.8100482857846063
# ====================
# grains rice dried goods 2.5794504312590965
# ====================
# red wines 1.2536254665546902
# ====================
# packaged produce 1.4934894972637078
# ====================
# specialty cheeses 2.026884802584048
# ====================
# packaged seafood 2.2347788901513415
# ====================
# spices seasonings 2.4253572657093
# ====================
# frozen vegan vegetarian 1.8708081295539487
# ====================
# yogurt 1.6868528758265835
# ====================
# canned meals beans 1.5207193160268189
# ====================
# instant foods 0.9750071912895081
# ====================
# mint gum 0.47298552694393187
# ====================
# ice cream toppings 1.0968692866158418
# ====================
# fruit vegetable snacks 1.3530816821826548
# ====================
# cereal 1.6081959554387346
# ====================
# latino foods 2.0744512111036673
# ====================
# dry pasta 2.3914223590514916
# ====================
# frozen dessert 0.9712701079368742
# ====================
# granola 1.904663037414577
# ====================
# baking supplies decor 1.1878356901633302
# ====================
# cocoa drink mixes 0.9771261381923793
# ====================
# oils vinegars 2.2578275828478667
# ====================
# cream 1.0683572142703215
# ====================
# prepared meals 1.1216504069532813
# ====================
# seafood counter 2.4469117072893547
# ====================
# bakery desserts 1.172374385646769
# ====================
# specialty wines champagnes 1.1275023532279624
# ====================
# soft drinks 0.5877457210911763
# ====================
# spreads 1.8695663535171714
# ====================
# breakfast bars pastries 0.6990464885931945
# ====================
# refrigerated 1.6168735790431676
# ====================
# hot cereal pancake mixes 1.801588915528622
# ====================
# nuts seeds dried fruit 1.6247456278442978
# ====================
# soup broth bouillon 1.3941966800804526
# ====================
# lunch meat 1.5473647752093929
# ====================
# frozen breakfast 1.1212457073295234
# ====================
# fresh pasta 2.054529363551189
# ====================
# white wines 1.1294672922079398
# ====================
# canned jarred vegetables 2.2145931330282385
# ====================
# energy granola bars 1.4709370754426256
# ====================
# poultry counter 2.183574832105556
# ====================
# baking ingredients 2.0264213261744666
# ====================
# honeys syrups nectars 1.944659932527374
# ====================
# frozen meat seafood 1.1495443508086283
# ====================
# bulk grains rice dried goods 3.1291761824908417
# ====================
# hot dogs bacon sausage 1.6792395925332033
# ====================
# packaged meat 1.649791627335307
# ====================
# asian foods 2.322087385604673
# ====================
# bread 1.9604922880828817
# ====================
# tofu meat alternatives 2.491498524902771
# ====================
# fresh herbs 2.9310565291669697
# ====================
# indian foods 2.122995334066222
# ====================
# frozen appetizers sides 1.0653993449326242
# ====================
# packaged poultry 1.870988241007237
# ====================
# frozen juice 1.0399514338822409
# ====================
# condiments 2.004907583297024
# ====================
# meat counter 2.4361353336804874
# ====================
# crackers 1.4396666963942324
# ====================
# juice nectars 1.3837646252983895
# ====================
# milk 1.668663495031789
# ====================
# other creams cheeses 1.5916253128196411
# ====================
# trail mix snack mix 0.9634255243411282
# ====================
# spirits 0.9567987921439435
# ====================
# frozen breads doughs 1.941784223140053
# ====================
# packaged cheese 1.6896491572413097
# ====================
# water seltzer sparkling water 1.239112564552592
# ====================
# buns rolls 1.482830323477423
# ====================
# doughs gelatins bake mixes 1.4210722038051204
# ====================
# fresh fruits 2.1364768203907745
# ====================
# bulk dried fruits vegetables 2.2577091884944296
# ====================
# eggs 2.1004976545045837
# ====================
# refrigerated pudding desserts 1.0508712509881477
# ====================
# frozen pizza 0.7212447554510947
# ====================
# pickled goods olives 1.9627563681988154
# ====================
# fresh dips tapenades 1.79067887398118
# ====================
# prepared soups salads 1.448007494535853
# ====================
# frozen produce 1.7552567997942226
# ====================
# tea 1.6290213434255987
# ====================
# pasta sauce 1.9266203231247623
# ====================
# preserved dips spreads 1.7477633195423563
# ====================
# canned fruit applesauce 1.3477984208784006
# ====================

# %%
# pour voir la healthiness d'un produit en particulier:
healthiness_per_aisle['packaged produce'][healthiness_per_aisle['packaged produce'].product_id==21385]
# Out:
#     product_id    product_name             aisle department  healthiness  \
# 18       21385  Butter Lettuce  packaged produce    produce     2.194175
#
#     count  fidelity
# 18    618  0.807941

# %%
# print proportion of products above the healthiness threshold for each aisle
for aisle in food_aisles:
    t = 0
    g = 0
    lst = []
    for ind in by_aisle[aisle]['product_id']:
        if ind in product_scores.index:
            lst.append(product_scores.at[ind, 'healthiness'])
        if ind in product_scores.index and product_scores.at[ind, 'healthiness']>=2:
            g += 1
        t+=1
    #print(by_aisle[aisle]['product_id'])
    print(aisle, float(g)/t, g, t)
    #print(sorted(lst))
# Out:
# butter 0.44666666666666666 67 150
# energy sports drinks 0.09863945578231292 29 294
# soy lactosefree 0.6109215017064846 179 293
# ice cream ice 0.3290559120073327 359 1091
# breakfast bakery 0.29646017699115046 67 226
# coffee 0.26029411764705884 177 680
# marinades meat preparation 0.45965770171149145 188 409
# kosher foods 0.591715976331361 100 169
# beers coolers 0.13246753246753246 51 385
# canned meat seafood 0.48056537102473496 136 283
# tortillas flat bread 0.5601659751037344 135 241
# frozen meals 0.05909090909090909 52 880
# cookies cakes 0.16590389016018306 145 874
# chips pretzels 0.32659251769464104 323 989
# packaged vegetables fruits 0.5349593495934959 329 615
# popcorn jerky 0.1930379746835443 61 316
# fresh vegetables 0.9332161687170475 531 569
# candy chocolate 0.19743178170144463 246 1246
# salad dressing toppings 0.45 252 560
# grains rice dried goods 0.7232142857142857 243 336
# red wines 0.24568965517241378 57 232
# packaged produce 0.125 4 32
# specialty cheeses 0.5608856088560885 152 271
# packaged seafood 0.6375 51 80
# spices seasonings 0.6963613550815558 555 797
# frozen vegan vegetarian 0.5185185185185185 98 189
# yogurt 0.4415204678362573 453 1026
# canned meals beans 0.4093567251461988 140 342
# instant foods 0.23941068139963168 130 543
# mint gum 0.1130952380952381 19 168
# ice cream toppings 0.24705882352941178 21 85
# fruit vegetable snacks 0.2949438202247191 105 356
# cereal 0.40748898678414097 185 454
# latino foods 0.5680933852140078 146 257
# dry pasta 0.7242888402625821 331 457
# frozen dessert 0.17857142857142858 20 112
# granola 0.4756756756756757 88 185
# baking supplies decor 0.28620689655172415 83 290
# cocoa drink mixes 0.2556053811659193 57 223
# oils vinegars 0.6426666666666667 241 375
# cream 0.2360248447204969 38 161
# prepared meals 0.27129337539432175 86 317
# seafood counter 0.7777777777777778 42 54
# bakery desserts 0.28619528619528617 85 297
# specialty wines champagnes 0.2 19 95
# soft drinks 0.12526997840172785 58 463
# spreads 0.5354969574036511 264 493
# breakfast bars pastries 0.07514450867052024 13 173
# refrigerated 0.3851851851851852 260 675
# hot cereal pancake mixes 0.4884488448844885 148 303
# nuts seeds dried fruit 0.41924398625429554 244 582
# soup broth bouillon 0.3378561736770692 249 737
# lunch meat 0.3378016085790885 126 373
# frozen breakfast 0.27364864864864863 81 296
# fresh pasta 0.6016260162601627 74 123
# white wines 0.20408163265306123 30 147
# canned jarred vegetables 0.6344969199178645 309 487
# energy granola bars 0.3173076923076923 264 832
# poultry counter 0.6341463414634146 52 82
# baking ingredients 0.5682182985553772 354 623
# honeys syrups nectars 0.537117903930131 123 229
# frozen meat seafood 0.22270742358078602 51 229
# bulk grains rice dried goods 1.0 26 26
# hot dogs bacon sausage 0.39276485788113696 152 387
# packaged meat 0.4 40 100
# asian foods 0.6595041322314049 399 605
# bread 0.5385996409335727 300 557
# tofu meat alternatives 0.779874213836478 124 159
# fresh herbs 0.8488372093023255 73 86
# indian foods 0.5185185185185185 56 108
# frozen appetizers sides 0.22797927461139897 88 386
# packaged poultry 0.494949494949495 49 99
# frozen juice 0.1702127659574468 8 47
# condiments 0.5364806866952789 250 466
# meat counter 0.7142857142857143 75 105
# crackers 0.3748326639892905 280 747
# juice nectars 0.3522727272727273 279 792
# milk 0.4279835390946502 104 243
# other creams cheeses 0.41361256544502617 79 191
# trail mix snack mix 0.2028985507246377 14 69
# spirits 0.15897435897435896 31 195
# frozen breads doughs 0.5802469135802469 47 81
# packaged cheese 0.43546576879910215 388 891
# water seltzer sparkling water 0.25290697674418605 87 344
# buns rolls 0.3435897435897436 67 195
# doughs gelatins bake mixes 0.3412526997840173 158 463
# fresh fruits 0.6151832460732984 235 382
# bulk dried fruits vegetables 0.6666666666666666 8 12
# eggs 0.6 75 125
# refrigerated pudding desserts 0.17346938775510204 17 98
# frozen pizza 0.15223880597014924 51 335
# pickled goods olives 0.5223880597014925 210 402
# fresh dips tapenades 0.5107033639143731 167 327
# prepared soups salads 0.3082191780821918 45 146
# frozen produce 0.481994459833795 174 361
# tea 0.38031319910514544 340 894
# pasta sauce 0.5413533834586466 216 399
# preserved dips spreads 0.45454545454545453 120 264
# canned fruit applesauce 0.27983539094650206 68 243

# %%
product_scores.sort_values(by="healthiness").head()
# Out:
#             healthiness  count  fidelity
# product_id
# 32114              -1.0      1  0.000000
# 30980              -1.0      1  0.000000
# 30993              -1.0      1  0.000000
# 30998              -1.0      2  0.000000
# 31011              -1.0      3  0.821429

# %% [markdown]
# The very first idea coming to mind when one wants to improve people's consumption habits is to make them consume healthy products. The problem of this approach is the requirement of a "healthiness score" that is not easy to evaluate.
# A second approach would be to advise products that consumers usually like. Again, this will bring us to define an "appreciation score" reflecting how likely a consumer is to re-buy this product.
#
#
# # I - Healthiness score
#
# No information concerning the products' healthiness is provided in the datasets. By clustering the users according to their consumptions in each aisle, we can separate them into more or less healthy groups. Now, we define the healthiness of a production as a function of the distribution of people who consumed this product.
# For instance, if a "healthy" user consumes a certain product, it gives 4 points to this product. An "average" consumer would give 1 point, while an "unhealthy" consumer would remove 1 point to the product. Then, it is easy to adapt this (arbitrary) scores making a weighted average taking the number of consumptions into account. The bigger the score, the healthier the product.
# In particular, if a product has a score of -1, it means that it's only consumed by people of the unhealthy cluster, and a product rated 4 is only conumed by people of the healthy cluster.
# The healthiness score may be irrelevant when a product is only consumed by very few people, because it introduces a great variance in score evaluation.
#
# ## II - Appreciation score
#
# We can decude from our dataset the average number of times a product is re-bought. Nevertheless, we have to take the consumer's consumption habits into account. For instance, imagine a consumer, Ada, buying everytime the same set of products, and bought each of them 10 times, except one product, let's say "chicory and ham", which wasn't so good, and she bought it only 4 times. Now imagine  a second consumer Robert, who doesn't like consuming the same products, and tries to have a very varied consumption. He bought once each product, except one, say "goat cheese", which he loved and bought 3 times. If Ada and Robert are the only consumers of the dataset, "chicory and ham" would have a better appreciation score (that is 4) than "goat cheese" (score of 3). We don't want this to happen !
# This is why we normalize the contribution of each user by the average time he or she consumes each product. Then, we avarege the scores obtained for each user, and obtain a general appreciation score for the product. The greater, the more the product is likely to be re-bought. The score itself is difficult to  interpret, but we can compare different scores quite safely.
#
# ## III - Limitations
#
# Some products have been consumed by very few people, sometimes 0, so we have no (reliable) information about their scores. A quick exploration of these products show that they are not products we would want to advise, because they are too specific. As an example, we can mention and . Our decision for these products is to give them a score of 0.
